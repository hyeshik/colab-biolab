# %% [markdown]
# # 생물정보학 및 실습 1 실습용 Terminal 환경 셋업
#
# ```
# 생물정보학 및 실습 1
# 서울대학교 협동과정 생물정보학전공 2021년 1학기
#
# 이 노트북은 Creative Commons BY-SA 조건으로 재사용 가능합니다.
# 장혜식 <hyeshik@snu.ac.kr>, 서울대학교 생명과학부
# ```
#
# 이 노트북은 Google Colab을 이용해서 Linux shell 실습을 할 수 있도록 Terminal을 열고 환경을 준비해줍니다. Google Colab은 창을 닫은 후 90분 후, 또는 창을 처음 열고 12시간 후에 환경을 닫아버리기 때문에 매번 실습할 때마다 새로 셋업이 필요합니다. `Runtime->Run All`을 실행해서 전체를 한 번 실행하시면 준비됩니다. 모든 것이 잘 안 되고 뭔가 꼬인 느낌이 강하게 들 때는 `Runtime->Factory reset runtime`을 누르고 새로 시작하시면 될 수도 있습니다.

# %% [markdown]
# ## Google Drive 마운트
#
# 데이터 파일들을 불러오고 저장하기 위해서 Google Drive를 연결합니다. 화면에 나오는 주소를 눌러서 인증하고 인증 코드를 그 아래에 입력하세요. 그러면 `/contents/drive/MyDrive`에서 자신의 Drive 최상단 폴더가 보입니다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 실습용 Bioconda 환경 설치하기
# 실습용 프로그램들을 쉽게 설치할 수 있도록 [Bioconda](https://bioconda.github.io/) 환경을 만듭니다. 실행하고 진행상황을 관찰하다가 에러로 보이는 것이 있으면 잘 읽어보고 해결합니다.
#
# 파이썬 모듈들은 Colab쪽의 파이썬 인터프리터를 바꿀 수 없기 때문에 Conda에 설치하더라도 사용하기 어렵습니다. 파이썬 모듈은 `pip` 명령어로 설치하시면 Colab에서 불러와서 사용할 수 있습니다.
#
# 환경 초기화에 관련된 스크립트는 [GitHub 프로젝트](https://github.com/hyeshik/colab-biolab)에 있습니다.

# %%
# !git clone https://github.com/hyeshik/colab-biolab.git
# !cd colab-biolab && bash tools/setup.sh
exec(open('colab-biolab/tools/activate_conda.py').read())

# %% [markdown]
# 설정이 끝났으면, 이제 콘솔을 열어서 터미널로 접속할 수 있는 통로를 열어줍니다.

# %% [markdown]
# ## 터미널 열기
# 명령행 작업을 쉽게 하기 위해서 터미널을 열어줍니다. 아래 셀을 실행하면 터미널을 띄울 수 있는 주소가 열립니다.

# %%
# !pip install kora
from kora import console
console.start()  # and click link

# %% [markdown]
# ⬆️ 위의 https://teleconsole.com 으로 시작하는 주소를 클릭해서 창을 열면 터미널이 새로 열립니다. 그 터미널 창은 현재 보고 계시는 노트북과 연결되어 있어서 설치되는 프로그램 등이 공유됩니다. 404 에러가 나면 위 셀을 다시 실행해주세요.

# %% [markdown]
# ## 본격 실습용 데이터 설치!
# 이제 실습 수업에서 필요한 시퀀싱 데이터, Annotation 데이터 등을 다운로드 받아서 설치합시다. Colab에서는 작업용 데이터를 `/content`에 저장합니다. 실습용 데이터는 `/content/binfo1`에 풀어두도록 하겠습니다. 여기에 저장되는 파일들은 일정 시간이 되면 모두 지워지니까, 영구히 보관하고 싶은 데이터는 Google Drive 위치인 `/content/drive/MyDrive`에 보관하시면 나중에 다시 불러오거나, 자기 컴퓨터에서 불러올 수 있습니다.

# %%
# !mkdir -p /content/binfo1
# !wget -O - --no-check-certificate https://hyeshik.qbio.io/binfo/commandline-20210304.tar.gz | tar -C /content/binfo1 -xzf -
# !bash /content/binfo1/initialize.sh
print('Done! \U0001f600')

# %% [markdown]
# ## 잘 되는지 한 번..
# Shell 명령은 터미널에서 작업하는 게 좀 더 편하기는 하지만, Colab에서 보낼 수도 있습니다. 잘 되는지 확인하는 겸, Colab에서 한 번 실행해 봅시다.

# %%
# %cd /content/binfo1

# %%
# 2세포기 mouse embryo에서 poly(A)가 10nt인 것들 중에 혹시 genome에서 encoding된 poly(A)가 있는지 찾아봄.
# !samtools view -f128 -F16 alignments/C2.bam | grep 'Za:i:10	' | cut -f6 | sort | uniq -c | sort -nr | head
